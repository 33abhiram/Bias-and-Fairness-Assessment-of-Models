# %% [markdown]
# # Coding Assignment: Data Bias

# %% [markdown]
# ### Hypothesis: The Perspective API will make more mistakes on shorter or more informal pieces of content (like tweets and social media comments) compared to longer ones (like book and movie and reviews) To test my hypothesis, I have gathered 16 short comments and 16 long comments from various social media platforms, customer reviews and blog posts, and tested them with the Perspective API client to check whether it correctly classifies them as toxic or non toxic.

# %%
import numpy as np
import pandas as pd
from googleapiclient import discovery
import json

# load the dataset in 3 column format : type, human_label, comment
df = pd.read_csv("data_bias.csv")
df
# Out:
#       type human_label                                            comment
# 0    short   non toxic                  follow me on instagram @33abhiram
# 1    short   non toxic                           Cmon what are you doing?
# 2    short   non toxic                            Did you vote for Obama?
# 3    short   non toxic                           You're just plain wrong.
# 4    short   non toxic                     I dont have any muslim friends
# 5    short   non toxic           I dont have any african american friends
# 6    short   non toxic                he passed away a couple days ago :(
# 7    short   non toxic                Americans have no general knowledge
# 8   short        toxic                       You're an absolute disgrace.
# 9   short        toxic                                 wtf are you doing!
# 10  short        toxic                     You're a total waste of space.
# 11  short        toxic           I wish u weren't allowed in our country!
# 12  short        toxic                                you are so retarded
# 13  short        toxic      33abhiram his instagram feed is so horrific.
# 14   short       toxic                Women should'nt be allowed to drive
# 15   short       toxic                        I'm done with your bullshit
# 16    long   non toxic  How could you miss such a crucial day! Today i...
# 17    long   non toxic  How can you say this! Trent Boult is probably ...
# 18    long   non toxic  These days the police are doing a horrible job...
# 19    long   non toxic  I think Afghanistan has the worst cricket team...
# 20    long   non toxic  If the Taliban did not invade Afghanistan, the...
# 21    long   non toxic  This whole thread is a joke. The lack of commo...
# 22    long   non toxic  I cant stand you! You really need to work on y...
# 23    long   non toxic  Lol this is so freaking funny! The average sal...
# 24    long       toxic  This is ridiculous! Can't believe people are s...
# 25    long       toxic  Your opinion is totally baseless and lacks any...
# 26    long       toxic  Why bother discussing this when there's a clea...
# 27    long       toxic  I'm so tired of hearing your pointless opinion...
# 28    long       toxic  Your whole instagram feed is hilarious. The fa...
# 29    long       toxic  I really do not think that women should be all...
# 30    long       toxic  Pakistani players should be banned from the IP...
# 31    long       toxic  Women Basketball players are literally so aver...

# %%
# Function that uses the Perspective API client to score each comment
def get_perspective_score(comment):
    API_KEY = "AIzaSyDcnow7xd_AmASuqLHuTDSIP7YZza5f0K4"

    client = discovery.build(
        "commentanalyzer",
        "v1alpha1",
        developerKey=API_KEY,
        discoveryServiceUrl="https://commentanalyzer.googleapis.com/$discovery/rest?version=v1alpha1",
        static_discovery=False,
    )

    analyze_request = {
        "comment": {"text": comment},
        "requestedAttributes": {"TOXICITY": {}},
    }

    response = client.comments().analyze(body=analyze_request).execute()
    perspective_score = response['attributeScores']['TOXICITY']['spanScores'][0]['score']['value']

    return perspective_score

# Test the function
get_perspective_score("This is a test comment")
# Out:
# 0.017341165

# %%
# Use the get_perspective_score function to score each comment and create a new column perspective_score
df["perspective_score"] = df["comment"].apply(get_perspective_score)
df
# Out:
#       type human_label                                            comment  \
# 0    short   non toxic                  follow me on instagram @33abhiram
# 1    short   non toxic                           Cmon what are you doing?
# 2    short   non toxic                            Did you vote for Obama?
# 3    short   non toxic                           You're just plain wrong.
# 4    short   non toxic                     I dont have any muslim friends
# 5    short   non toxic           I dont have any african american friends
# 6    short   non toxic                he passed away a couple days ago :(
# 7    short   non toxic                Americans have no general knowledge
# 8   short        toxic                       You're an absolute disgrace.
# 9   short        toxic                                 wtf are you doing!
# 10  short        toxic                     You're a total waste of space.
# 11  short        toxic           I wish u weren't allowed in our country!
# 12  short        toxic                                you are so retarded
# 13  short        toxic      33abhiram his instagram feed is so horrific.
# 14   short       toxic                Women should'nt be allowed to drive
# 15   short       toxic                        I'm done with your bullshit
# 16    long   non toxic  How could you miss such a crucial day! Today i...
# 17    long   non toxic  How can you say this! Trent Boult is probably ...
# 18    long   non toxic  These days the police are doing a horrible job...
# 19    long   non toxic  I think Afghanistan has the worst cricket team...
# 20    long   non toxic  If the Taliban did not invade Afghanistan, the...
# 21    long   non toxic  This whole thread is a joke. The lack of commo...
# 22    long   non toxic  I cant stand you! You really need to work on y...
# 23    long   non toxic  Lol this is so freaking funny! The average sal...
# 24    long       toxic  This is ridiculous! Can't believe people are s...
# 25    long       toxic  Your opinion is totally baseless and lacks any...
# 26    long       toxic  Why bother discussing this when there's a clea...
# 27    long       toxic  I'm so tired of hearing your pointless opinion...
# 28    long       toxic  Your whole instagram feed is hilarious. The fa...
# 29    long       toxic  I really do not think that women should be all...
# 30    long       toxic  Pakistani players should be banned from the IP...
# 31    long       toxic  Women Basketball players are literally so aver...
#
#     perspective_score
# 0            0.044636
# 1            0.072920
# 2            0.024967
# 3            0.157667
# 4            0.377512
# 5            0.502472
# 6            0.019854
# 7            0.397729
# 8            0.749544
# 9            0.571686
# 10           0.584095
# 11           0.485019
# 12           0.846027
# 13           0.338998
# 14           0.588517
# 15           0.920998
# 16           0.080834
# 17           0.377512
# 18           0.505032
# 19           0.329712
# 20           0.169385
# 21           0.377512
# 22           0.439841
# 23           0.301366
# 24           0.572199
# 25           0.505032
# 26           0.519808
# 27           0.535794
# 28           0.439468
# 29           0.505032
# 30           0.507592
# 31           0.571686

# %%
# Create a new column api_label to label each comment based on the perspective_score
df["api_label"] = [1 if score > 0.5 else 0 for score in df["perspective_score"]]
df
# Out:
#       type human_label                                            comment  \
# 0    short   non toxic                  follow me on instagram @33abhiram
# 1    short   non toxic                           Cmon what are you doing?
# 2    short   non toxic                            Did you vote for Obama?
# 3    short   non toxic                           You're just plain wrong.
# 4    short   non toxic                     I dont have any muslim friends
# 5    short   non toxic           I dont have any african american friends
# 6    short   non toxic                he passed away a couple days ago :(
# 7    short   non toxic                Americans have no general knowledge
# 8   short        toxic                       You're an absolute disgrace.
# 9   short        toxic                                 wtf are you doing!
# 10  short        toxic                     You're a total waste of space.
# 11  short        toxic           I wish u weren't allowed in our country!
# 12  short        toxic                                you are so retarded
# 13  short        toxic      33abhiram his instagram feed is so horrific.
# 14   short       toxic                Women should'nt be allowed to drive
# 15   short       toxic                        I'm done with your bullshit
# 16    long   non toxic  How could you miss such a crucial day! Today i...
# 17    long   non toxic  How can you say this! Trent Boult is probably ...
# 18    long   non toxic  These days the police are doing a horrible job...
# 19    long   non toxic  I think Afghanistan has the worst cricket team...
# 20    long   non toxic  If the Taliban did not invade Afghanistan, the...
# 21    long   non toxic  This whole thread is a joke. The lack of commo...
# 22    long   non toxic  I cant stand you! You really need to work on y...
# 23    long   non toxic  Lol this is so freaking funny! The average sal...
# 24    long       toxic  This is ridiculous! Can't believe people are s...
# 25    long       toxic  Your opinion is totally baseless and lacks any...
# 26    long       toxic  Why bother discussing this when there's a clea...
# 27    long       toxic  I'm so tired of hearing your pointless opinion...
# 28    long       toxic  Your whole instagram feed is hilarious. The fa...
# 29    long       toxic  I really do not think that women should be all...
# 30    long       toxic  Pakistani players should be banned from the IP...
# 31    long       toxic  Women Basketball players are literally so aver...
#
#     perspective_score  api_label
# 0            0.044636          0
# 1            0.072920          0
# 2            0.024967          0
# 3            0.157667          0
# 4            0.377512          0
# 5            0.502472          1
# 6            0.019854          0
# 7            0.397729          0
# 8            0.749544          1
# 9            0.571686          1
# 10           0.584095          1
# 11           0.485019          0
# 12           0.846027          1
# 13           0.338998          0
# 14           0.588517          1
# 15           0.920998          1
# 16           0.080834          0
# 17           0.377512          0
# 18           0.505032          1
# 19           0.329712          0
# 20           0.169385          0
# 21           0.377512          0
# 22           0.439841          0
# 23           0.301366          0
# 24           0.572199          1
# 25           0.505032          1
# 26           0.519808          1
# 27           0.535794          1
# 28           0.439468          0
# 29           0.505032          1
# 30           0.507592          1
# 31           0.571686          1

# %%
# Convert human_label to binary
df["human_label"] = [1 if x=='toxic' else 0 for x in df['human_label']]
df
# Out:
#       type  human_label                                            comment  \
# 0    short            0                  follow me on instagram @33abhiram
# 1    short            0                           Cmon what are you doing?
# 2    short            0                            Did you vote for Obama?
# 3    short            0                           You're just plain wrong.
# 4    short            0                     I dont have any muslim friends
# 5    short            0           I dont have any african american friends
# 6    short            0                he passed away a couple days ago :(
# 7    short            0                Americans have no general knowledge
# 8   short             1                       You're an absolute disgrace.
# 9   short             1                                 wtf are you doing!
# 10  short             1                     You're a total waste of space.
# 11  short             1           I wish u weren't allowed in our country!
# 12  short             1                                you are so retarded
# 13  short             1      33abhiram his instagram feed is so horrific.
# 14   short            1                Women should'nt be allowed to drive
# 15   short            1                        I'm done with your bullshit
# 16    long            0  How could you miss such a crucial day! Today i...
# 17    long            0  How can you say this! Trent Boult is probably ...
# 18    long            0  These days the police are doing a horrible job...
# 19    long            0  I think Afghanistan has the worst cricket team...
# 20    long            0  If the Taliban did not invade Afghanistan, the...
# 21    long            0  This whole thread is a joke. The lack of commo...
# 22    long            0  I cant stand you! You really need to work on y...
# 23    long            0  Lol this is so freaking funny! The average sal...
# 24    long            1  This is ridiculous! Can't believe people are s...
# 25    long            1  Your opinion is totally baseless and lacks any...
# 26    long            1  Why bother discussing this when there's a clea...
# 27    long            1  I'm so tired of hearing your pointless opinion...
# 28    long            1  Your whole instagram feed is hilarious. The fa...
# 29    long            1  I really do not think that women should be all...
# 30    long            1  Pakistani players should be banned from the IP...
# 31    long            1  Women Basketball players are literally so aver...
#
#     perspective_score  api_label
# 0            0.044636          0
# 1            0.072920          0
# 2            0.024967          0
# 3            0.157667          0
# 4            0.377512          0
# 5            0.502472          1
# 6            0.019854          0
# 7            0.397729          0
# 8            0.749544          1
# 9            0.571686          1
# 10           0.584095          1
# 11           0.485019          0
# 12           0.846027          1
# 13           0.338998          0
# 14           0.588517          1
# 15           0.920998          1
# 16           0.080834          0
# 17           0.377512          0
# 18           0.505032          1
# 19           0.329712          0
# 20           0.169385          0
# 21           0.377512          0
# 22           0.439841          0
# 23           0.301366          0
# 24           0.572199          1
# 25           0.505032          1
# 26           0.519808          1
# 27           0.535794          1
# 28           0.439468          0
# 29           0.505032          1
# 30           0.507592          1
# 31           0.571686          1

# %%
# Select relevant columns for testing
df = df[["type", "human_label", "api_label"]]
df
# Out:
#       type  human_label  api_label
# 0    short            0          0
# 1    short            0          0
# 2    short            0          0
# 3    short            0          0
# 4    short            0          0
# 5    short            0          1
# 6    short            0          0
# 7    short            0          0
# 8   short             1          1
# 9   short             1          1
# 10  short             1          1
# 11  short             1          0
# 12  short             1          1
# 13  short             1          0
# 14   short            1          1
# 15   short            1          1
# 16    long            0          0
# 17    long            0          0
# 18    long            0          1
# 19    long            0          0
# 20    long            0          0
# 21    long            0          0
# 22    long            0          0
# 23    long            0          0
# 24    long            1          1
# 25    long            1          1
# 26    long            1          1
# 27    long            1          1
# 28    long            1          0
# 29    long            1          1
# 30    long            1          1
# 31    long            1          1

# %%
# Extract indices for short and long comments (first step of finding accuracy)
type_column = df["type"]

short_indices = []
long_indices = []
y_actual = [y for y in df['human_label']]
y_predicted = [y for y in df['api_label']]

for i in range(len(type_column)):
    if type_column[i] == "long":
        long_indices.append(i)
    else:
        short_indices.append(i)

y_actual_short = [y_actual[i] for i in short_indices]
y_predicted_short = [y_predicted[i] for i in short_indices]

y_actual_long = [y_actual[i] for i in long_indices]
y_predicted_long = [y_predicted[i] for i in long_indices]

print(len(short_indices))
print(len(long_indices))
# Out:
# 16
# 16

# %%
# Define function to find class wise accuracy of comments
def class_wise_acc(y_actual, y_predicted):
    total_p = 0
    total_n = 0
    TP=0
    TN=0
    for i in range(len(y_predicted)):
        if y_actual[i]==1:
            total_p = total_p+1
            if y_actual[i]==y_predicted[i]:
               TP=TP+1
        if y_actual[i]==0:
            total_n=total_n+1
            if y_actual[i]==y_predicted[i]:
               TN=TN+1
    return(TP/total_p, TN/total_n)

class_1_acc_short, class_0_acc_short = class_wise_acc(y_actual_short, y_predicted_short)
class_1_acc_long, class_0_acc_long = class_wise_acc(y_actual_long, y_predicted_long)

print (f"Accuracy for short, non toxic comments = {class_0_acc_short}")
print (f"Accuracy for short, toxic comments = {class_1_acc_short}")
print (f"Accuracy for long, non toxic comments = {class_0_acc_long}")
print (f"Accuracy for long, toxic comments = {class_1_acc_long}")
# Out:
# Accuracy for short, non toxic comments = 0.875
# Accuracy for short, toxic comments = 0.75
# Accuracy for long, non toxic comments = 0.875
# Accuracy for long, toxic comments = 0.875

# %% [markdown]
# ### Insights: Based on my results, the accuracy of the model drops by 12.5% for short toxic comments compared to longer ones, suggesting a potential bias in its performance. This difference implies that the model may be predisposed to struggle with shorter, more informal content commonly found in social media comments and tweets.
#
# ### The informal nature of shorter comments, especially in the form of slang and expressions found in social media comments and tweets, may introduce bias by making it more challenging for the Perspective API to accurately interpret and classify toxicity. Longer comments like book and movie reviews offer a more comprehensive language context, which potentially reduces any bias in the API model's evaluation.
#
# ### These findings suggest that users should be mindful of the model's potential limitations and biases in scenarios where content length and informality are involved.
